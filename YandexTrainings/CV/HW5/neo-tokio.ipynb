# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.pipeline import make_pipeline
import lightgbm as lgb
from lightgbm import LGBMClassifier
import optuna
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import PCA
from sklearn.ensemble import StackingClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("train.csv")
validation_data = pd.read_csv("test.csv")
X, y = data.drop('target', axis = 1), data['target']

# %%
ros = RandomOverSampler(random_state=42)
X_train, y_train = ros.fit_resample(X, y)

# %%
def objective(trial):

    # Feature pipeline
    pipeline = make_pipeline(
        StandardScaler(),
        PolynomialFeatures(degree=2),
    )

    X_trans = pd.DataFrame(pipeline.fit_transform(X_train), columns = pipeline.get_feature_names_out())

    # Parameters for base models
    lgbm_params = {
        'objective': 'binary',
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        'num_leaves': trial.suggest_int('num_leaves', 8, 64),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 0.2, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 10, 32),
        'random_state': 42,
        'n_jobs': -1,
    }

    xgb_params = {
        'objective': 'binary:logistic',
        'learning_rate': trial.suggest_float('xgb_learning_rate', 1e-2, 0.2, log=True),
        'n_estimators': trial.suggest_int('xgb_n_estimators', 100, 500),
        'max_depth': trial.suggest_int('xgb_max_depth', 10, 32),
        'n_jobs': -1,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }

    base_models = [
        ('lgbm', lgb.LGBMClassifier(**lgbm_params)),
        ('xgb', XGBClassifier(**xgb_params)),
    ]

    # Stacking ensemble
    model = StackingClassifier(
        estimators=base_models,
        final_estimator=LogisticRegression(max_iter = trial.suggest_int('max_iter', 500, 10000), random_state=42),
        passthrough=True,
        n_jobs=-1
    )

    # Cross-validation
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    y_pred_proba = cross_val_predict(model, X_trans, y_train, cv=cv, method='predict_proba')[:, 1]

    # Best threshold
    fpr, tpr, thresholds = roc_curve(y_train, y_pred_proba)
    accuracies = [accuracy_score(y_train, y_pred_proba >= t) for t in thresholds]
    best_idx = np.argmax(accuracies)
    best_threshold = thresholds[best_idx]
    best_acc = accuracies[best_idx]

    trial.set_user_attr('best_threshold', best_threshold)
    return best_acc

# 2. Start optimization
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=100)

print("Лучшие параметры:", study.best_params)
print("Лучшее Accuracy:", study.best_value)
best_threshold = study.best_trial.user_attrs['best_threshold']
print(f"Лучший порог, сохраненный из objective: {best_threshold:.4f}")
# Out:
# [I 2025-04-27 13:45:18,673] A new study created in memory with name: no-name-80a0c07b-c646-457c-ae26-ef9a0b1d3736
# [I 2025-04-27 13:50:38,549] Trial 0 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 49, 'learning_rate': 0.060099747183803134, 'n_estimators': 162, 'max_depth': 13, 'xgb_learning_rate': 0.011900590783184251, 'xgb_n_estimators': 447, 'xgb_max_depth': 23, 'max_iter': 7227}. Best is trial 0 with value: 0.8934871099050203.
# [I 2025-04-27 13:54:00,035] Trial 1 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 55, 'learning_rate': 0.018891200276189388, 'n_estimators': 172, 'max_depth': 14, 'xgb_learning_rate': 0.024878734419814436, 'xgb_n_estimators': 310, 'xgb_max_depth': 19, 'max_iter': 3266}. Best is trial 0 with value: 0.8934871099050203.
# [I 2025-04-27 13:57:49,442] Trial 2 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.029967309097101588, 'n_estimators': 282, 'max_depth': 28, 'xgb_learning_rate': 0.018187859051288217, 'xgb_n_estimators': 306, 'xgb_max_depth': 23, 'max_iter': 941}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 13:59:56,576] Trial 3 finished with value: 0.8921302578018996 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 11, 'learning_rate': 0.17160445029754812, 'n_estimators': 487, 'max_depth': 28, 'xgb_learning_rate': 0.0249064396938244, 'xgb_n_estimators': 139, 'xgb_max_depth': 25, 'max_iter': 4681}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:02:46,715] Trial 4 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 9, 'learning_rate': 0.15242391728466367, 'n_estimators': 203, 'max_depth': 25, 'xgb_learning_rate': 0.02544166090938368, 'xgb_n_estimators': 308, 'xgb_max_depth': 22, 'max_iter': 2256}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:05:44,564] Trial 5 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 61, 'learning_rate': 0.1459476894296684, 'n_estimators': 339, 'max_depth': 31, 'xgb_learning_rate': 0.01303561122512888, 'xgb_n_estimators': 178, 'xgb_max_depth': 11, 'max_iter': 3590}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:10:29,617] Trial 6 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 55, 'learning_rate': 0.02911701023242742, 'n_estimators': 212, 'max_depth': 22, 'xgb_learning_rate': 0.015252697030515175, 'xgb_n_estimators': 421, 'xgb_max_depth': 11, 'max_iter': 9876}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:11:48,104] Trial 7 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 8, 'learning_rate': 0.11506408247250169, 'n_estimators': 383, 'max_depth': 26, 'xgb_learning_rate': 0.10079659367870726, 'xgb_n_estimators': 129, 'xgb_max_depth': 18, 'max_iter': 1600}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:13:42,781] Trial 8 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 26, 'learning_rate': 0.012097379927033842, 'n_estimators': 224, 'max_depth': 17, 'xgb_learning_rate': 0.08896916672592671, 'xgb_n_estimators': 355, 'xgb_max_depth': 30, 'max_iter': 4986}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:16:57,138] Trial 9 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'dart', 'num_leaves': 51, 'learning_rate': 0.05373267600451109, 'n_estimators': 409, 'max_depth': 21, 'xgb_learning_rate': 0.04787304927324382, 'xgb_n_estimators': 271, 'xgb_max_depth': 10, 'max_iter': 1525}. Best is trial 2 with value: 0.8955223880597015.
# [I 2025-04-27 14:19:27,409] Trial 10 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 33, 'learning_rate': 0.030180553031924535, 'n_estimators': 291, 'max_depth': 32, 'xgb_learning_rate': 0.050557344004285465, 'xgb_n_estimators': 237, 'xgb_max_depth': 31, 'max_iter': 7575}. Best is trial 10 with value: 0.8968792401628223.
# [I 2025-04-27 14:21:46,531] Trial 11 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 32, 'learning_rate': 0.029059314335235016, 'n_estimators': 285, 'max_depth': 32, 'xgb_learning_rate': 0.05751505862151099, 'xgb_n_estimators': 227, 'xgb_max_depth': 32, 'max_iter': 7244}. Best is trial 10 with value: 0.8968792401628223.
# [I 2025-04-27 14:24:27,722] Trial 12 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.03181081977381053, 'n_estimators': 294, 'max_depth': 29, 'xgb_learning_rate': 0.03637179768148346, 'xgb_n_estimators': 239, 'xgb_max_depth': 27, 'max_iter': 7114}. Best is trial 10 with value: 0.8968792401628223.
# [I 2025-04-27 14:26:30,463] Trial 13 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 41, 'learning_rate': 0.01596779599257903, 'n_estimators': 107, 'max_depth': 32, 'xgb_learning_rate': 0.06753572548530251, 'xgb_n_estimators': 371, 'xgb_max_depth': 16, 'max_iter': 9866}. Best is trial 10 with value: 0.8968792401628223.
# [I 2025-04-27 14:27:52,403] Trial 14 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.07554183616070062, 'n_estimators': 266, 'max_depth': 24, 'xgb_learning_rate': 0.1483997448107215, 'xgb_n_estimators': 213, 'xgb_max_depth': 28, 'max_iter': 8295}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:29:07,639] Trial 15 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.08347051809010067, 'n_estimators': 353, 'max_depth': 20, 'xgb_learning_rate': 0.18989090587064478, 'xgb_n_estimators': 204, 'xgb_max_depth': 28, 'max_iter': 8206}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:30:25,813] Trial 16 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 37, 'learning_rate': 0.04271985406828158, 'n_estimators': 261, 'max_depth': 10, 'xgb_learning_rate': 0.1705381742933193, 'xgb_n_estimators': 100, 'xgb_max_depth': 32, 'max_iter': 8384}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:31:59,944] Trial 17 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.08105493834761791, 'n_estimators': 441, 'max_depth': 24, 'xgb_learning_rate': 0.12681028556572102, 'xgb_n_estimators': 165, 'xgb_max_depth': 28, 'max_iter': 6101}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:33:50,481] Trial 18 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'dart', 'num_leaves': 33, 'learning_rate': 0.08847621543545296, 'n_estimators': 323, 'max_depth': 18, 'xgb_learning_rate': 0.1328665202323963, 'xgb_n_estimators': 246, 'xgb_max_depth': 30, 'max_iter': 8646}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:35:57,464] Trial 19 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 45, 'learning_rate': 0.08798276807031823, 'n_estimators': 336, 'max_depth': 18, 'xgb_learning_rate': 0.139314492051757, 'xgb_n_estimators': 275, 'xgb_max_depth': 26, 'max_iter': 8996}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:38:15,734] Trial 20 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'dart', 'num_leaves': 29, 'learning_rate': 0.10862215529526902, 'n_estimators': 378, 'max_depth': 19, 'xgb_learning_rate': 0.08694166161689394, 'xgb_n_estimators': 357, 'xgb_max_depth': 29, 'max_iter': 5859}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:40:04,309] Trial 21 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'dart', 'num_leaves': 35, 'learning_rate': 0.06161559280309667, 'n_estimators': 255, 'max_depth': 15, 'xgb_learning_rate': 0.12614733402524617, 'xgb_n_estimators': 236, 'xgb_max_depth': 31, 'max_iter': 8502}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:41:53,692] Trial 22 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 19, 'learning_rate': 0.03686274807234886, 'n_estimators': 319, 'max_depth': 23, 'xgb_learning_rate': 0.06836231391508552, 'xgb_n_estimators': 196, 'xgb_max_depth': 25, 'max_iter': 7645}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:44:52,524] Trial 23 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 39, 'learning_rate': 0.020833636305069236, 'n_estimators': 259, 'max_depth': 26, 'xgb_learning_rate': 0.035848166295974246, 'xgb_n_estimators': 264, 'xgb_max_depth': 30, 'max_iter': 6382}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:46:27,859] Trial 24 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.04937267143351015, 'n_estimators': 298, 'max_depth': 17, 'xgb_learning_rate': 0.14738105423140477, 'xgb_n_estimators': 215, 'xgb_max_depth': 29, 'max_iter': 9140}. Best is trial 14 with value: 0.8975576662143826.
# [I 2025-04-27 14:47:42,955] Trial 25 finished with value: 0.898236092265943 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.06344502132388632, 'n_estimators': 235, 'max_depth': 30, 'xgb_learning_rate': 0.19907919525772444, 'xgb_n_estimators': 261, 'xgb_max_depth': 32, 'max_iter': 9200}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:48:57,569] Trial 26 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.07100062983869436, 'n_estimators': 236, 'max_depth': 29, 'xgb_learning_rate': 0.19466669948965803, 'xgb_n_estimators': 335, 'xgb_max_depth': 26, 'max_iter': 9039}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:50:30,141] Trial 27 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 14, 'learning_rate': 0.10622167108769463, 'n_estimators': 183, 'max_depth': 21, 'xgb_learning_rate': 0.11005220484364424, 'xgb_n_estimators': 485, 'xgb_max_depth': 32, 'max_iter': 9352}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:51:42,152] Trial 28 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.19475404082814868, 'n_estimators': 135, 'max_depth': 16, 'xgb_learning_rate': 0.17302353273257406, 'xgb_n_estimators': 266, 'xgb_max_depth': 28, 'max_iter': 8102}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:53:37,278] Trial 29 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 22, 'learning_rate': 0.06096250308631218, 'n_estimators': 138, 'max_depth': 11, 'xgb_learning_rate': 0.07685736372645573, 'xgb_n_estimators': 410, 'xgb_max_depth': 24, 'max_iter': 6837}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:54:57,255] Trial 30 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 14, 'learning_rate': 0.12619809387035996, 'n_estimators': 234, 'max_depth': 13, 'xgb_learning_rate': 0.10961365538355401, 'xgb_n_estimators': 176, 'xgb_max_depth': 21, 'max_iter': 9841}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:56:15,625] Trial 31 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.18231968976338814, 'n_estimators': 149, 'max_depth': 16, 'xgb_learning_rate': 0.15992745324367966, 'xgb_n_estimators': 267, 'xgb_max_depth': 28, 'max_iter': 8009}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:57:29,053] Trial 32 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 26, 'learning_rate': 0.09219689731255166, 'n_estimators': 191, 'max_depth': 14, 'xgb_learning_rate': 0.19922622407025492, 'xgb_n_estimators': 292, 'xgb_max_depth': 30, 'max_iter': 8596}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 14:58:36,247] Trial 33 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 22, 'learning_rate': 0.06990382934290744, 'n_estimators': 110, 'max_depth': 19, 'xgb_learning_rate': 0.15695927153829448, 'xgb_n_estimators': 255, 'xgb_max_depth': 29, 'max_iter': 7923}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:00:07,237] Trial 34 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'dart', 'num_leaves': 29, 'learning_rate': 0.041857279808634226, 'n_estimators': 166, 'max_depth': 12, 'xgb_learning_rate': 0.12685186420174538, 'xgb_n_estimators': 317, 'xgb_max_depth': 27, 'max_iter': 6724}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:01:27,413] Trial 35 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'dart', 'num_leaves': 41, 'learning_rate': 0.12769292851058553, 'n_estimators': 131, 'max_depth': 15, 'xgb_learning_rate': 0.1702334891835535, 'xgb_n_estimators': 285, 'xgb_max_depth': 24, 'max_iter': 4188}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:02:51,232] Trial 36 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'dart', 'num_leaves': 13, 'learning_rate': 0.15575312008676118, 'n_estimators': 324, 'max_depth': 30, 'xgb_learning_rate': 0.09896874842708965, 'xgb_n_estimators': 205, 'xgb_max_depth': 21, 'max_iter': 9404}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:04:00,945] Trial 37 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 25, 'learning_rate': 0.19861749091687533, 'n_estimators': 360, 'max_depth': 27, 'xgb_learning_rate': 0.1380063333761892, 'xgb_n_estimators': 152, 'xgb_max_depth': 15, 'max_iter': 5601}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:05:50,955] Trial 38 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'dart', 'num_leaves': 34, 'learning_rate': 0.09860404225511823, 'n_estimators': 268, 'max_depth': 23, 'xgb_learning_rate': 0.11655523309291954, 'xgb_n_estimators': 326, 'xgb_max_depth': 31, 'max_iter': 8785}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:09:55,808] Trial 39 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.05203246263444459, 'n_estimators': 203, 'max_depth': 18, 'xgb_learning_rate': 0.010709859573364766, 'xgb_n_estimators': 303, 'xgb_max_depth': 23, 'max_iter': 7574}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:11:06,097] Trial 40 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.07051461385617853, 'n_estimators': 314, 'max_depth': 25, 'xgb_learning_rate': 0.16838241615728494, 'xgb_n_estimators': 188, 'xgb_max_depth': 26, 'max_iter': 9566}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:12:18,134] Trial 41 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 12, 'learning_rate': 0.12622455520366704, 'n_estimators': 238, 'max_depth': 14, 'xgb_learning_rate': 0.10633332875135679, 'xgb_n_estimators': 172, 'xgb_max_depth': 21, 'max_iter': 9937}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:13:31,292] Trial 42 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 15, 'learning_rate': 0.13400149763612268, 'n_estimators': 222, 'max_depth': 16, 'xgb_learning_rate': 0.09367541048479558, 'xgb_n_estimators': 129, 'xgb_max_depth': 13, 'max_iter': 8743}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:14:37,302] Trial 43 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 10, 'learning_rate': 0.16164024529501164, 'n_estimators': 242, 'max_depth': 13, 'xgb_learning_rate': 0.14470530823232614, 'xgb_n_estimators': 248, 'xgb_max_depth': 18, 'max_iter': 2785}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:26:08,051] Trial 44 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.14220013946437152, 'n_estimators': 272, 'max_depth': 13, 'xgb_learning_rate': 0.19995964464887336, 'xgb_n_estimators': 217, 'xgb_max_depth': 20, 'max_iter': 9562}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:27:20,515] Trial 45 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 27, 'learning_rate': 0.0762736103991169, 'n_estimators': 178, 'max_depth': 16, 'xgb_learning_rate': 0.165930611510895, 'xgb_n_estimators': 158, 'xgb_max_depth': 30, 'max_iter': 8137}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:28:45,867] Trial 46 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 8, 'learning_rate': 0.11649928106177815, 'n_estimators': 404, 'max_depth': 20, 'xgb_learning_rate': 0.08197321702087819, 'xgb_n_estimators': 185, 'xgb_max_depth': 27, 'max_iter': 7445}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:32:04,851] Trial 47 finished with value: 0.8921302578018996 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.17610695336777077, 'n_estimators': 499, 'max_depth': 12, 'xgb_learning_rate': 0.01701876880948966, 'xgb_n_estimators': 227, 'xgb_max_depth': 32, 'max_iter': 9925}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:33:38,125] Trial 48 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 30, 'learning_rate': 0.10101665851537696, 'n_estimators': 222, 'max_depth': 22, 'xgb_learning_rate': 0.11168765125726815, 'xgb_n_estimators': 249, 'xgb_max_depth': 22, 'max_iter': 797}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:36:36,474] Trial 49 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'dart', 'num_leaves': 16, 'learning_rate': 0.11899314311112853, 'n_estimators': 203, 'max_depth': 28, 'xgb_learning_rate': 0.02334146512152178, 'xgb_n_estimators': 287, 'xgb_max_depth': 31, 'max_iter': 8413}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:38:01,302] Trial 50 finished with value: 0.898236092265943 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.059773703797713316, 'n_estimators': 310, 'max_depth': 18, 'xgb_learning_rate': 0.12216497577089463, 'xgb_n_estimators': 146, 'xgb_max_depth': 16, 'max_iter': 9060}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:39:24,061] Trial 51 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.06566302713680819, 'n_estimators': 308, 'max_depth': 17, 'xgb_learning_rate': 0.12921567751435076, 'xgb_n_estimators': 140, 'xgb_max_depth': 16, 'max_iter': 9156}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:40:39,538] Trial 52 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 37, 'learning_rate': 0.08773650579863922, 'n_estimators': 287, 'max_depth': 19, 'xgb_learning_rate': 0.17976449508716, 'xgb_n_estimators': 118, 'xgb_max_depth': 13, 'max_iter': 8818}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:42:40,558] Trial 53 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 62, 'learning_rate': 0.05359176638485613, 'n_estimators': 347, 'max_depth': 18, 'xgb_learning_rate': 0.14074192646487052, 'xgb_n_estimators': 180, 'xgb_max_depth': 13, 'max_iter': 7870}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:46:25,953] Trial 54 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.057415136189806384, 'n_estimators': 331, 'max_depth': 15, 'xgb_learning_rate': 0.1519462900809325, 'xgb_n_estimators': 104, 'xgb_max_depth': 19, 'max_iter': 9681}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:48:11,384] Trial 55 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 32, 'learning_rate': 0.07700303721776838, 'n_estimators': 278, 'max_depth': 20, 'xgb_learning_rate': 0.11713071106706063, 'xgb_n_estimators': 226, 'xgb_max_depth': 17, 'max_iter': 9251}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:50:19,685] Trial 56 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 25, 'learning_rate': 0.09466285009065847, 'n_estimators': 302, 'max_depth': 30, 'xgb_learning_rate': 0.058771835987242796, 'xgb_n_estimators': 200, 'xgb_max_depth': 29, 'max_iter': 8378}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:52:08,947] Trial 57 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'dart', 'num_leaves': 27, 'learning_rate': 0.04668431316824442, 'n_estimators': 374, 'max_depth': 10, 'xgb_learning_rate': 0.09872611295371365, 'xgb_n_estimators': 146, 'xgb_max_depth': 28, 'max_iter': 7038}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:55:32,017] Trial 58 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 57, 'learning_rate': 0.038615754629831626, 'n_estimators': 445, 'max_depth': 17, 'xgb_learning_rate': 0.04236106769998699, 'xgb_n_estimators': 169, 'xgb_max_depth': 25, 'max_iter': 8944}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:57:18,724] Trial 59 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'dart', 'num_leaves': 11, 'learning_rate': 0.06277610170829583, 'n_estimators': 253, 'max_depth': 22, 'xgb_learning_rate': 0.07571611604050729, 'xgb_n_estimators': 214, 'xgb_max_depth': 31, 'max_iter': 9577}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 15:58:42,800] Trial 60 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 45, 'learning_rate': 0.14490116131432032, 'n_estimators': 154, 'max_depth': 27, 'xgb_learning_rate': 0.18089752381490184, 'xgb_n_estimators': 257, 'xgb_max_depth': 14, 'max_iter': 8193}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:01:30,851] Trial 61 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.05155190887971797, 'n_estimators': 204, 'max_depth': 18, 'xgb_learning_rate': 0.034625423067835226, 'xgb_n_estimators': 296, 'xgb_max_depth': 22, 'max_iter': 7617}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:05:01,039] Trial 62 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.07745979814811466, 'n_estimators': 192, 'max_depth': 19, 'xgb_learning_rate': 0.020861338405234024, 'xgb_n_estimators': 311, 'xgb_max_depth': 23, 'max_iter': 8609}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:06:29,029] Trial 63 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.03454449860928059, 'n_estimators': 247, 'max_depth': 21, 'xgb_learning_rate': 0.1312674965318126, 'xgb_n_estimators': 277, 'xgb_max_depth': 24, 'max_iter': 7745}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:10:00,852] Trial 64 finished with value: 0.898236092265943 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 14, 'learning_rate': 0.04452549433291666, 'n_estimators': 220, 'max_depth': 18, 'xgb_learning_rate': 0.010191854650559672, 'xgb_n_estimators': 233, 'xgb_max_depth': 19, 'max_iter': 7311}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:13:31,601] Trial 65 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 15, 'learning_rate': 0.05710460654406053, 'n_estimators': 230, 'max_depth': 15, 'xgb_learning_rate': 0.014217695776601784, 'xgb_n_estimators': 240, 'xgb_max_depth': 18, 'max_iter': 4756}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:14:47,162] Trial 66 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 14, 'learning_rate': 0.044998613406801447, 'n_estimators': 283, 'max_depth': 16, 'xgb_learning_rate': 0.15445310927722533, 'xgb_n_estimators': 231, 'xgb_max_depth': 19, 'max_iter': 9210}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:17:40,126] Trial 67 finished with value: 0.8941655359565808 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 12, 'learning_rate': 0.023678292751213106, 'n_estimators': 263, 'max_depth': 24, 'xgb_learning_rate': 0.028154974107013328, 'xgb_n_estimators': 264, 'xgb_max_depth': 30, 'max_iter': 7265}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:19:19,106] Trial 68 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'dart', 'num_leaves': 35, 'learning_rate': 0.0836304733600618, 'n_estimators': 216, 'max_depth': 20, 'xgb_learning_rate': 0.11968205584530904, 'xgb_n_estimators': 197, 'xgb_max_depth': 16, 'max_iter': 6661}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:20:28,136] Trial 69 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.06845411267618315, 'n_estimators': 120, 'max_depth': 14, 'xgb_learning_rate': 0.17731332656646775, 'xgb_n_estimators': 214, 'xgb_max_depth': 17, 'max_iter': 8381}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:21:57,284] Trial 70 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 20, 'learning_rate': 0.19761218842473652, 'n_estimators': 299, 'max_depth': 17, 'xgb_learning_rate': 0.1384978127519664, 'xgb_n_estimators': 159, 'xgb_max_depth': 32, 'max_iter': 6366}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:26:07,328] Trial 71 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.04136173904798657, 'n_estimators': 165, 'max_depth': 19, 'xgb_learning_rate': 0.010100656732931021, 'xgb_n_estimators': 277, 'xgb_max_depth': 19, 'max_iter': 7448}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:31:10,248] Trial 72 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 29, 'learning_rate': 0.05814070560336125, 'n_estimators': 191, 'max_depth': 18, 'xgb_learning_rate': 0.011419180507685053, 'xgb_n_estimators': 352, 'xgb_max_depth': 20, 'max_iter': 7941}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:34:58,354] Trial 73 finished with value: 0.8914518317503393 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 20, 'learning_rate': 0.010397606014041468, 'n_estimators': 209, 'max_depth': 21, 'xgb_learning_rate': 0.011414705302966432, 'xgb_n_estimators': 244, 'xgb_max_depth': 23, 'max_iter': 8922}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:39:15,571] Trial 74 finished with value: 0.898236092265943 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.05077624385580201, 'n_estimators': 231, 'max_depth': 18, 'xgb_learning_rate': 0.01182091170976001, 'xgb_n_estimators': 299, 'xgb_max_depth': 20, 'max_iter': 8585}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:43:01,995] Trial 75 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 17, 'learning_rate': 0.04669112756246877, 'n_estimators': 233, 'max_depth': 18, 'xgb_learning_rate': 0.013254239804392918, 'xgb_n_estimators': 260, 'xgb_max_depth': 20, 'max_iter': 9433}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:44:51,450] Trial 76 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 26, 'learning_rate': 0.10874660367643202, 'n_estimators': 249, 'max_depth': 16, 'xgb_learning_rate': 0.10375157447517057, 'xgb_n_estimators': 334, 'xgb_max_depth': 21, 'max_iter': 8655}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:49:44,357] Trial 77 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'dart', 'num_leaves': 10, 'learning_rate': 0.04870161634264046, 'n_estimators': 327, 'max_depth': 17, 'xgb_learning_rate': 0.012002987954221686, 'xgb_n_estimators': 384, 'xgb_max_depth': 17, 'max_iter': 8240}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:52:44,766] Trial 78 finished with value: 0.898236092265943 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 15, 'learning_rate': 0.02639625848338128, 'n_estimators': 270, 'max_depth': 20, 'xgb_learning_rate': 0.01619386159518995, 'xgb_n_estimators': 190, 'xgb_max_depth': 22, 'max_iter': 9739}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:56:05,444] Trial 79 finished with value: 0.8975576662143826 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 16, 'learning_rate': 0.026701840161775132, 'n_estimators': 277, 'max_depth': 22, 'xgb_learning_rate': 0.015809690895316586, 'xgb_n_estimators': 222, 'xgb_max_depth': 29, 'max_iter': 9317}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 16:59:32,396] Trial 80 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 24, 'learning_rate': 0.014951517545210152, 'n_estimators': 344, 'max_depth': 31, 'xgb_learning_rate': 0.012913749017498801, 'xgb_n_estimators': 205, 'xgb_max_depth': 11, 'max_iter': 5260}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:02:27,376] Trial 81 finished with value: 0.8887381275440976 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 14, 'learning_rate': 0.01714968925645094, 'n_estimators': 100, 'max_depth': 20, 'xgb_learning_rate': 0.01000529250175628, 'xgb_n_estimators': 188, 'xgb_max_depth': 28, 'max_iter': 9721}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:04:58,684] Trial 82 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.03237144267443087, 'n_estimators': 314, 'max_depth': 20, 'xgb_learning_rate': 0.018357586144928998, 'xgb_n_estimators': 130, 'xgb_max_depth': 21, 'max_iter': 8958}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:06:08,892] Trial 83 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 13, 'learning_rate': 0.07231833248184615, 'n_estimators': 294, 'max_depth': 18, 'xgb_learning_rate': 0.19005193496746725, 'xgb_n_estimators': 237, 'xgb_max_depth': 27, 'max_iter': 9816}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:07:27,752] Trial 84 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 16, 'learning_rate': 0.0648264064406473, 'n_estimators': 266, 'max_depth': 19, 'xgb_learning_rate': 0.15681246930716902, 'xgb_n_estimators': 284, 'xgb_max_depth': 22, 'max_iter': 9954}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:10:29,529] Trial 85 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'dart', 'num_leaves': 33, 'learning_rate': 0.08332226386020036, 'n_estimators': 257, 'max_depth': 17, 'xgb_learning_rate': 0.012581931301459388, 'xgb_n_estimators': 169, 'xgb_max_depth': 20, 'max_iter': 8618}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:14:32,795] Trial 86 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.02036043876014883, 'n_estimators': 360, 'max_depth': 19, 'xgb_learning_rate': 0.013812463318660676, 'xgb_n_estimators': 272, 'xgb_max_depth': 25, 'max_iter': 3816}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:17:25,443] Trial 87 finished with value: 0.8955223880597015 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.08865926392135488, 'n_estimators': 241, 'max_depth': 12, 'xgb_learning_rate': 0.010820264181063155, 'xgb_n_estimators': 179, 'xgb_max_depth': 30, 'max_iter': 9041}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:21:13,512] Trial 88 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'dart', 'num_leaves': 28, 'learning_rate': 0.16597238114934748, 'n_estimators': 227, 'max_depth': 15, 'xgb_learning_rate': 0.014978368672799372, 'xgb_n_estimators': 252, 'xgb_max_depth': 22, 'max_iter': 1290}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:22:38,981] Trial 89 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 9, 'learning_rate': 0.05622697082231712, 'n_estimators': 215, 'max_depth': 23, 'xgb_learning_rate': 0.08963972437161644, 'xgb_n_estimators': 207, 'xgb_max_depth': 18, 'max_iter': 8065}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:23:53,353] Trial 90 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 12, 'learning_rate': 0.02712275329603388, 'n_estimators': 273, 'max_depth': 21, 'xgb_learning_rate': 0.16263000213156126, 'xgb_n_estimators': 301, 'xgb_max_depth': 31, 'max_iter': 9394}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:29:30,043] Trial 91 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.049930108067769145, 'n_estimators': 197, 'max_depth': 18, 'xgb_learning_rate': 0.01090936002933312, 'xgb_n_estimators': 457, 'xgb_max_depth': 23, 'max_iter': 7717}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:33:44,140] Trial 92 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 23, 'learning_rate': 0.04092727877984196, 'n_estimators': 138, 'max_depth': 17, 'xgb_learning_rate': 0.012289312344509718, 'xgb_n_estimators': 308, 'xgb_max_depth': 26, 'max_iter': 8435}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:38:02,130] Trial 93 finished with value: 0.8962008141112618 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 15, 'learning_rate': 0.05298556669829014, 'n_estimators': 172, 'max_depth': 16, 'xgb_learning_rate': 0.010709978205021882, 'xgb_n_estimators': 299, 'xgb_max_depth': 19, 'max_iter': 8792}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:39:38,778] Trial 94 finished with value: 0.8968792401628223 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 25, 'learning_rate': 0.036588306402555025, 'n_estimators': 245, 'max_depth': 18, 'xgb_learning_rate': 0.14549092875443767, 'xgb_n_estimators': 317, 'xgb_max_depth': 21, 'max_iter': 7147}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:41:13,651] Trial 95 finished with value: 0.8934871099050203 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 19, 'learning_rate': 0.06405095297113099, 'n_estimators': 224, 'max_depth': 19, 'xgb_learning_rate': 0.12239433708734272, 'xgb_n_estimators': 283, 'xgb_max_depth': 27, 'max_iter': 9137}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:42:43,551] Trial 96 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 22, 'learning_rate': 0.10200461730173993, 'n_estimators': 256, 'max_depth': 20, 'xgb_learning_rate': 0.1328393972429557, 'xgb_n_estimators': 190, 'xgb_max_depth': 24, 'max_iter': 9656}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:44:12,535] Trial 97 finished with value: 0.89280868385346 and parameters: {'boosting_type': 'dart', 'num_leaves': 37, 'learning_rate': 0.07528300939972711, 'n_estimators': 183, 'max_depth': 27, 'xgb_learning_rate': 0.17606220523369803, 'xgb_n_estimators': 268, 'xgb_max_depth': 32, 'max_iter': 8200}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:46:45,690] Trial 98 finished with value: 0.8921302578018996 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 27, 'learning_rate': 0.13624277209762428, 'n_estimators': 306, 'max_depth': 25, 'xgb_learning_rate': 0.0286805336996497, 'xgb_n_estimators': 158, 'xgb_max_depth': 15, 'max_iter': 7473}. Best is trial 25 with value: 0.898236092265943.
# [I 2025-04-27 17:49:08,098] Trial 99 finished with value: 0.8948439620081411 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 18, 'learning_rate': 0.061385229711953565, 'n_estimators': 236, 'max_depth': 14, 'xgb_learning_rate': 0.056607634158855925, 'xgb_n_estimators': 326, 'xgb_max_depth': 23, 'max_iter': 9465}. Best is trial 25 with value: 0.898236092265943.
# Лучшие параметры: {'boosting_type': 'gbdt', 'num_leaves': 21, 'learning_rate': 0.06344502132388632, 'n_estimators': 235, 'max_depth': 30, 'xgb_learning_rate': 0.19907919525772444, 'xgb_n_estimators': 261, 'xgb_max_depth': 32, 'max_iter': 9200}
# Лучшее Accuracy: 0.898236092265943
# Лучший порог, сохраненный из objective: 0.5865

# %%
# 3. Final model with the best parameters
best_max_iter = study.best_params.pop('max_iter')

pipeline = make_pipeline(
    StandardScaler(),
    PolynomialFeatures(degree=2),
)

X_train_transformed = pd.DataFrame(pipeline.fit_transform(X_train), columns = pipeline.get_feature_names_out())
validation_data_transformed = pd.DataFrame(pipeline.transform(validation_data), columns = pipeline.get_feature_names_out())

# LGBM
best_lgbm = lgb.LGBMClassifier(
    **{k: v for k, v in study.best_params.items() if k.startswith(('boosting_type', 'num_leaves', 'learning_rate', 'n_estimators', 'max_depth', 'subsample', 'colsample_bytree', 'reg_alpha', 'reg_lambda'))},
    random_state=42
)

# XGB (с удалением префикса)
best_xgb = XGBClassifier(
    **{k.replace('xgb_', ''): v for k, v in study.best_params.items() if k.startswith('xgb_')},
    random_state=42, use_label_encoder=False, eval_metric='logloss'
)


best_model = StackingClassifier(
    estimators=[
        ('lgbm', best_lgbm),
        ('xgb', best_xgb),
    ],
    final_estimator=LogisticRegression(max_iter=best_max_iter, random_state=42),
    passthrough=True,
    n_jobs=-1
)

best_model.fit(X_train_transformed, y_train)

# 4. Validation
val_proba = best_model.predict_proba(validation_data_transformed)[:, 1]
val_pred = (val_proba >= best_threshold).astype(int)


print("Validation complete.")
# Out:
# Validation complete.

# %%
df_answer = pd.DataFrame({'Prediction': val_pred})
df_answer.to_csv('answer.csv', index=False, header=False)
