# %%
# !pip install Cython==0.29.36
# Out:
# ...
#    ---------------------------------------- 0.0/988.3 kB ? eta -:--:--
#    ---------------------------------------- 988.3/988.3 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.11
#     Uninstalling Cython-3.0.11:
#       Successfully uninstalled Cython-3.0.11
# ...

# %%
# !pip install pysph
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [189 lines of output]
# ...
#     Using cached Beaker-1.13.0-py3-none-any.whl
# ...
#     Using cached Cython-3.0.12-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# ...
#     Using cached compyle-0.8.1.tar.gz (125 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#     Using cached cyarray-1.1.tar.gz (27 kB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
# ...
#     Using cached Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# ...
